# %% [markdown]
# # Домашнее задание: линейная регрессия

# %%
import pandas as pd

# %% [markdown]
# Сперва загрузим датасет в Python

# %%
data = pd.read_csv('Fish.csv')
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# Данный датасет представляет собой набор данных о рыбном маркете, где каждый объект соответствует одной отдельной рыбе и ее характеристикам (вид, вес, длина, высота, ширина).
#
# Данный датасет взять с [Kaggle](https://www.kaggle.com/datasets/vipullrathod/fish-market/data). Оттуда же можно взять подробное описание всех признаков в датасете.
#
# >The fish market dataset is a collection of data related to various species of fish and their characteristics. This dataset is designed for polynomial regression analysis and contains several columns with specific information. Here's a description of each column in the dataset:
#
# >Species: This column represents the species of the fish. It is a categorical variable that categorizes each fish into one of seven species. The species may include names like "Perch," "Bream," "Roach," "Pike," "Smelt," "Parkki," and "Whitefish." This column is the target variable for the polynomial regression analysis, where we aim to predict the fish's weight based on its other attributes.
#
# >Weight: This column represents the weight of the fish. It is a numerical variable that is typically measured in grams. The weight is the dependent variable we want to predict using polynomial regression.
#
# >Length1: This column represents the first measurement of the fish's length. It is a numerical variable, typically measured in centimetres.
#
# >Length2: This column represents the second measurement of the fish's length. It is another numerical variable, typically measured in centimetres.
#
# >Length3: This column represents the third measurement of the fish's length. Similar to the previous two columns, it is a numerical variable, usually measured in centimetres.
#
# >Height: This column represents the height of the fish. It is a numerical variable, typically measured in centimetres.
#
# >Width: This column represents the width of the fish. Like the other numerical variables, it is also typically measured in centimetres.
#
# >The dataset is structured in such a way that each row corresponds to a single fish with its species and various physical measurements (lengths, height, and width). The goal of using polynomial regression on this dataset would be to build a predictive model that can estimate the weight of a fish based on its species and the provided physical measurements. Polynomial regression allows for modelling more complex relationships between the independent variables (lengths, height, and width) and the dependent variable (weight), which may be particularly useful if there are non-linear patterns in the data.

# %% [markdown]
# Мы решаем задачу прогнозирования веса рыбы по ее характеристикам.

# %% [markdown]
# ## Предварительный анализ данных

# %% [markdown]
# Посмотрим, есть ли пропущенные значения в датасете

# %%
# YOUR CODE

# %% [markdown]
# > Какие выводы можно сделать о пропущенных значениях? Нужно ли заполнять пропущенные значения? Если нужно, то как?

# %% [markdown]
# Рассмотрим таблицу описательных статистик для датасета

# %%
# YOUR CODE

# %% [markdown]
# > Какие средние значения для каждого признака? Какие среднеквадратичные отклонения? Какие максимальные и минимальные значения?

# %% [markdown]
# В данном наборе данных присутствует некоторая особенность -- неоднородность данных. То есть интуитивно все данные можно разбить группы по видам рыб. Интуитивно мы понимаем, что у каждого вида будут схожие характеристики между собой. Однако они могут различаться между видами.
#
# Сперва рассмотрим, насколько сбалансированы данные по каждому виду рыбы

# %%
data['Species'].value_counts()
# Out:
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: count, dtype: int64

# %% [markdown]
# В группах сильный дисбаланс. Поэтому зависимость таргета Weight с остальными признаками мы будем рассматривать отдельно для каждого вида рыбы, чтобы ничего не упустить.
#
# Определим зависимый и независимые признаки и запишем названия этих столбцов в отдельные переменные (пока что Species не считает признаком, поскольку сейчас мы будем рассматривать характеристики для каждого конкретного вида)

# %%
features = ['Length1', 'Length2', 'Length3', 'Height', 'Width']
target = 'Weight'

# %% [markdown]
# Также все возможные виды рыб запишем в отдельную переменную

# %%
species = # YOUR CODE
species

# %% [markdown]
# С помощью библиотеки Plotly построим диаграммы рассеяния по видам рыб каждой фичи с таргетом

# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

for feature in features:
    fig = make_subplots(rows=1, cols=7, subplot_titles=species, x_title=feature, y_title=target)

    for i, specie in enumerate(species, start=1):
        col = (i % 7) + 1

        filtered_data = data[data['Species'] == specie]

        scatter_trace = go.Scatter(
            x=filtered_data[feature],
            y=filtered_data[target],
            mode='markers',
            name=specie
        )

        fig.add_trace(scatter_trace, row=1, col=col)

    fig.update_layout(height=300, width=1300)
    fig.show()

# %% [markdown]
# > Какие выводы о взаимосвязях между фичами и таргетом можно сделать? Сказывается ли неоднородность в данных на взаимосвязях?

# %% [markdown]
# Также рассмотрим соответствующие гистограммы распределений

# %%
variables = [feature for feature in features]
variables.append(target)
variables
# Out:
# ['Length1', 'Length2', 'Length3', 'Height', 'Width', 'Weight']

# %%
for variable in variables:
    fig = make_subplots(rows=1, cols=7, subplot_titles=species, x_title=variable, y_title='Count')

    for i, specie in enumerate(species, start=1):
        col = (i % 7) + 1

        filtered_data = data[data['Species'] == specie]

        histogram_trace = go.Histogram(
            x=filtered_data[variable],
            name=specie,
            marker=dict(color=px.colors.qualitative.Set1[i % len(px.colors.qualitative.Set1)]),
            showlegend=False
        )

        fig.add_trace(histogram_trace, row=1, col=col)

    fig.update_layout(
        height=300,
        width=1300,
        bargap=0.2,
    )
    fig.show()

# %% [markdown]
# > Какие выводы можно сделать о распределениях? Схожи ли они между собой? Схожи ли они с нормальным распределением?
#
# > Есть ли какие-то специфики между видами рыб для распределений Weight?
#
# Теперь попробуем объединить всё в одну матрицу диаграмм рассеяния и сравнить с предыдущими выводами

# %%
# YOUR CODE

# Hint: Используйте sns.pairplot, его мы рассматривали на семинаре

# %% [markdown]
# > Сильно ли изменились результаты? Если да, то для каких конкретно переменных?

# %% [markdown]
# Проверим гипотезы о нормальном распределении

# %%
from scipy.stats import kstest, norm, pearsonr

for column in data[variables]:

    random_variable = data[column]

    mean = np.mean(random_variable)
    std = np.std(random_variable)
    theoretical_distribution = norm(loc=mean, scale=std)

    statistic, p_value = kstest(random_variable, theoretical_distribution.cdf)

    print(f"Значения параметров нормального распределения случайной величины {column}: {mean}, {std}")
    print(f"P-значение: {p_value}")

    alpha = 0.05
    if p_value < alpha:
        print(f"Гипотеза о нормальном распределении {column} отклоняется.")
    else:
        print(f"Гипотеза о нормальном распределении {column} принимается.")

    print('\n')
# Out:
# Значения параметров нормального распределения случайной величины Length1: 26.247169811320756, 9.96495627814052
# P-значение: 0.3959225403554635
# Гипотеза о нормальном распределении Length1 принимается.
#
#
# Значения параметров нормального распределения случайной величины Length2: 28.415723270440253, 10.68257580056147
# P-значение: 0.4142428388716072
# Гипотеза о нормальном распределении Length2 принимается.
#
#
# Значения параметров нормального распределения случайной величины Length3: 31.227044025157234, 11.573678038449334
# P-значение: 0.3435162793586344
# Гипотеза о нормальном распределении Length3 принимается.
#
#
# Значения параметров нормального распределения случайной величины Height: 8.970993710691824, 4.27270771991657
# P-значение: 0.016236686860181808
# Гипотеза о нормальном распределении Height отклоняется.
#
#
# Значения параметров нормального распределения случайной величины Width: 4.417485534591195, 1.6804942383152872
# P-значение: 0.5949738743434541
# Гипотеза о нормальном распределении Width принимается.
#
#
# Значения параметров нормального распределения случайной величины Weight: 398.3264150943396, 356.8508229894959
# P-значение: 0.00040988285817278227
# Гипотеза о нормальном распределении Weight отклоняется.

# %% [markdown]
# Гипотеза о нормальном распределении была отклонена для `Height`, хотя значение достаточно близко к пороговому. Однако мы всё же будем считать, что `Height` распределена нормально. Поскольку из гистограмм видно, что проблемы могло вызвать лишь распределение `Height` для `Parkki`. Для остальных же видов рыб гистограммы схожи с "колоколом" нормального распределения.
#
# Другая проблема у нас возникает с нашей целевой переменной -- `Weight`. Проверим гипотезу о нормальном распределении для каждого конкретного вида рыбы

# %%
for specie in species:

    random_variable = data[data['Species'] == specie][target]

    mean = np.mean(random_variable)
    std = np.std(random_variable)
    theoretical_distribution = norm(loc=mean, scale=std)

    statistic, p_value = kstest(random_variable, theoretical_distribution.cdf)

    print(f"Значения параметров нормального распределения случайной величины Weight для {specie}: {mean}, {std}")
    print(f"P-значение: {p_value}")

    alpha = 0.05
    if p_value < alpha:
        print(f"Гипотеза о нормальном распределении Weight для {specie} отклоняется.")
    else:
        print(f"Гипотеза о нормальном распределении Weight для {specie} принимается.")

    print('\n')
# Out:
# Значения параметров нормального распределения случайной величины Weight для Bream: 617.8285714285714, 206.19539771977531
# P-значение: 0.6893969429054044
# Гипотеза о нормальном распределении Weight для Bream принимается.
#
#
# Значения параметров нормального распределения случайной величины Weight для Roach: 152.05, 86.57971760175705
# P-значение: 0.5282414742066976
# Гипотеза о нормальном распределении Weight для Roach принимается.
#
#
# Значения параметров нормального распределения случайной величины Weight для Whitefish: 531.0, 282.6275523251994
# P-значение: 0.6111373280441859
# Гипотеза о нормальном распределении Weight для Whitefish принимается.
#
#
# Значения параметров нормального распределения случайной величины Weight для Parkki: 154.8181818181818, 75.0900286102903
# P-значение: 0.8919475578460732
# Гипотеза о нормальном распределении Weight для Parkki принимается.
#
#
# Значения параметров нормального распределения случайной величины Weight для Perch: 382.23928571428576, 344.50000657193203
# P-значение: 0.002483717444384359
# Гипотеза о нормальном распределении Weight для Perch отклоняется.
#
#
# Значения параметров нормального распределения случайной величины Weight для Pike: 718.7058823529412, 479.38695713513135
# P-значение: 0.13525020534799814
# Гипотеза о нормальном распределении Weight для Pike принимается.
#
#
# Значения параметров нормального распределения случайной величины Weight для Smelt: 11.178571428571429, 3.981237885638186
# P-значение: 0.2557174916514713
# Гипотеза о нормальном распределении Weight для Smelt принимается.

# %% [markdown]
# Таким образом, гипотеза отклоняется толкьо для `Perch`. Следовательно, вопреки отклонению гипотезы о нормальном распределении для неоднородного случая, мы будем считать, что целевая переменная Weight в целом распределена нормально.

# %% [markdown]
# Напоследок разберемся с истинной корреляцией. Рассмотрим гипотезу о нулевой корреляции между фичами и таргетом. Здесь мы будем рассматривать эти гипотезы для неоднородного случая (то есть не разделяя рыб по видам).

# %%
# YOUR CODE

# Hint: используйте функцию pearsonr для data[features] и data[target]. Аналогичная функция написана в ноутбуке с семинара.

# %% [markdown]
# > Таким образом, для каких фичей мы можем считать корреляцию нулевой?
#
# Исключим из data те фичи, для которых корреляция нулевая и построим корреляционную матрицу

# %%
# YOUR CODE

# Hint: для исключения фичи (если нужно исключить) используйте data.drop
# Hint: для корреляционной матрицы используйте метод .corr() или визуализацию sns.heatmap
# Пример, как это делать, был рассмотрен в ноутбуке на семинаре

# %% [markdown]
# Перед построением модели у нас осталась одна последняя неразрешенная проблема: в нашем датасете присутствует категориальный текстовый признак Species. Нам нужно закодировать его с помощью чисел.
# В качестве простейшего способа кодирования будем использовать One-Hot-Encoding

# %%
# YOUR CODE

# Hint: самостоятельно найдите способ правильно преобризовать Species.
# Hint: можете почитать про get_dummies в Pandas или OneHotEncoder в sklearn
# Hint: учитывайте, что категориальный признак вида:      sex
#                                                         man
#                                                         man
#                                                         woman
# создаст две one-hot фичи
#                                                         sex_man sex_woman
#                                                         1       0
#                                                         1       0
#                                                         0       1
# это может вызвать проблему мультиколлинеарности признаков. поэтому заранее предусмотрите этот момент. и за ненадобностью можно удалить один из one-hot признаков,
# чтобы получилось
#                                                         sex_man
#                                                         1
#                                                         1
#                                                         0
# то есть один оставшийся признак несет в себе достаточно ифнормации о том, какого пола объект

# %% [markdown]
# ## Построение модели линейной регресии

# %% [markdown]
# Сперва обозначим всю выборку через $X$ (фичи) и $y$ (таргет)

# %%
X = data.drop(columns='Weight')
y = data[target]

# %% [markdown]
# Приведем $X$ и $y$ к стандартному виду (среднее = 0, среднеквадратичное отклонение = 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = scaler.fit_transform(X)
y = scaler.fit_transform(pd.DataFrame(y))

# %% [markdown]
# Убедимся в том, что все данные были преобразованы как надо

# %%
# YOUR CODE
# Hint: имеется в виду метод .describe()

# %% [markdown]
# Разделим всю выборку на train и test наборы

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = # YOUR CODE

# %% [markdown]
# Теперь воспользуемся уже готовой реализацией модели линейной регрессии из библиотеки sklearn

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %% [markdown]
# Обучим модель на train выборке

# %%
# YOUR CODE

# %% [markdown]
# Рассмотрим значения метрик $MSE$ и $R^2$ на тестовом наборе

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_hat = # YOUR CODE
# Hint: вычислите прогнозы модели на обучающем наборе

train_mse = mean_squared_error(y_train, y_hat)
train_r2 = r2_score(y_train, y_hat)

print(f'Значение MSE на Train наборе {train_mse}')
print(f'Значение R^2 на Train наборе {train_r2}')

# %% [markdown]
# > Какие выводы можно сделать о значениях метрик? MSE сильно высокая или принимает умеренные значения?
#
# > О чем свидетельствует значение R^2 ? Адекватна ли модель в смысле R^2 метрики?

# %% [markdown]
# Теперь рассмотрим значения метрик на тестовом наборе

# %%
y_pred = # YOUR CODE
# Hint: вычислите прогнозы модели на тестовом наборе

test_mse = mean_squared_error(y_test, y_pred)
test_r2 = r2_score(y_test, y_pred)

print(f'Значение MSE на Test наборе {test_mse}')
print(f'Значение R^2 на Test наборе {test_r2}')

# %% [markdown]
# > Какие выводы можно сделать о значениях метрик на тестовом наборе относительно метрик на обучающемся наборе?
#
# > Что можно сказать о переобучении? (т.е. метрики на тестовом наборе сильно выше, чем на тестовом?)э
#
# > Если возникло переобучение, то как можно было бы избавиться от него?

# %% [markdown]
# Завернём вычисление метрик в одну функцию

# %%
def metrics(y_train, y_hat, y_test, y_pred):

    train_mse = mean_squared_error(y_train, y_hat)
    train_r2 = r2_score(y_train, y_hat)

    print(f'Значение MSE на Train наборе {train_mse}')
    print(f'Значение R^2 на Train наборе {train_r2}')

    test_mse = mean_squared_error(y_test, y_pred)
    test_r2 = r2_score(y_test, y_pred)

    print(f'Значение MSE на Test наборе {test_mse}')
    print(f'Значение R^2 на Test наборе {test_r2}')

# %% [markdown]
# ## Модели с регуляризацией: Ridge и LASSO

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Ridge

# %% [markdown]
# Сперва рассмотрим результаты применения Ridge регрессии, то есть L2 регуляризации.
#
# Зададим сетку параметров

# %%
ridge_params = {'alpha': np.logspace(-3, 3, 50)}
ridge_params
# Out:
# {'alpha': array([1.00000000e-03, 1.32571137e-03, 1.75751062e-03, 2.32995181e-03,
#         3.08884360e-03, 4.09491506e-03, 5.42867544e-03, 7.19685673e-03,
#         9.54095476e-03, 1.26485522e-02, 1.67683294e-02, 2.22299648e-02,
#         2.94705170e-02, 3.90693994e-02, 5.17947468e-02, 6.86648845e-02,
#         9.10298178e-02, 1.20679264e-01, 1.59985872e-01, 2.12095089e-01,
#         2.81176870e-01, 3.72759372e-01, 4.94171336e-01, 6.55128557e-01,
#         8.68511374e-01, 1.15139540e+00, 1.52641797e+00, 2.02358965e+00,
#         2.68269580e+00, 3.55648031e+00, 4.71486636e+00, 6.25055193e+00,
#         8.28642773e+00, 1.09854114e+01, 1.45634848e+01, 1.93069773e+01,
#         2.55954792e+01, 3.39322177e+01, 4.49843267e+01, 5.96362332e+01,
#         7.90604321e+01, 1.04811313e+02, 1.38949549e+02, 1.84206997e+02,
#         2.44205309e+02, 3.23745754e+02, 4.29193426e+02, 5.68986603e+02,
#         7.54312006e+02, 1.00000000e+03])}

# %% [markdown]
# То есть под сеткой параметров понимается множество из 50 точек от $10^{-3}$ до $10^3$. Шаг между узлами (т.е. точками) сетки метод `np.logspace` подбирает автоматически.
#
# Далее создадим объект Ridge регрессии

# %%
ridge = Ridge()

# %% [markdown]
# Теперь мы будем подбирать наилучшее значение для параметра с помощью кросс-валидации.
#
# GridSearchCV позволяет запускать кросс-валидацию, выбирая последовательно каждое из значений параметра на сетке и подставляя его.
#
# В этом алгоритме можно указывать
# - cv : различные значения разбиений на fold-ы,
# - scroing : различные метрики (в нашем случае `neg_mean_squared_error` - это MSE, `r2` - это R^2),
# - verbose : различный формат вывода информации.
#
# Затем мы запускаем fit в этой модели, чтобы прогнать кросс-валидацию по всей сетке

# %%
ridge_cv = GridSearchCV(ridge, # модель
                        param_grid=ridge_params, # сетка параметров
                        cv=5, # количество fold-ов (разбиений) в кросс-валидации
                        scoring='neg_mean_squared_error', # метрика, которую мы минимизируем в кросс-валидации
                        verbose=3 # параметр равный 1, 2 или 3, который отвечает за выводимую информацию (можете самостоятельно покрутить его и посмотреть)
                       )

ridge_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END ......................alpha=0.001;, score=-0.045 total time=   0.0s
# [CV 2/5] END ......................alpha=0.001;, score=-0.083 total time=   0.0s
# [CV 3/5] END ......................alpha=0.001;, score=-0.090 total time=   0.0s
# [CV 4/5] END ......................alpha=0.001;, score=-0.152 total time=   0.0s
# [CV 5/5] END ......................alpha=0.001;, score=-0.070 total time=   0.0s
# [CV 1/5] END ......alpha=0.0013257113655901094;, score=-0.045 total time=   0.0s
# [CV 2/5] END ......alpha=0.0013257113655901094;, score=-0.083 total time=   0.0s
# [CV 3/5] END ......alpha=0.0013257113655901094;, score=-0.090 total time=   0.0s
# [CV 4/5] END ......alpha=0.0013257113655901094;, score=-0.152 total time=   0.0s
# [CV 5/5] END ......alpha=0.0013257113655901094;, score=-0.070 total time=   0.0s
# [CV 1/5] END ......alpha=0.0017575106248547913;, score=-0.044 total time=   0.0s
# [CV 2/5] END ......alpha=0.0017575106248547913;, score=-0.083 total time=   0.0s
# [CV 3/5] END ......alpha=0.0017575106248547913;, score=-0.090 total time=   0.0s
# [CV 4/5] END ......alpha=0.0017575106248547913;, score=-0.152 total time=   0.0s
# [CV 5/5] END ......alpha=0.0017575106248547913;, score=-0.069 total time=   0.0s
# [CV 1/5] END .......alpha=0.002329951810515372;, score=-0.044 total time=   0.0s
# [CV 2/5] END .......alpha=0.002329951810515372;, score=-0.083 total time=   0.0s
# [CV 3/5] END .......alpha=0.002329951810515372;, score=-0.090 total time=   0.0s
# [CV 4/5] END .......alpha=0.002329951810515372;, score=-0.153 total time=   0.0s
# [CV 5/5] END .......alpha=0.002329951810515372;, score=-0.069 total time=   0.0s
# [CV 1/5] END ......alpha=0.0030888435964774815;, score=-0.044 total time=   0.0s
# [CV 2/5] END ......alpha=0.0030888435964774815;, score=-0.083 total time=   0.0s
# [CV 3/5] END ......alpha=0.0030888435964774815;, score=-0.089 total time=   0.0s
# [CV 4/5] END ......alpha=0.0030888435964774815;, score=-0.153 total time=   0.0s
# [CV 5/5] END ......alpha=0.0030888435964774815;, score=-0.069 total time=   0.0s
# [CV 1/5] END .......alpha=0.004094915062380427;, score=-0.044 total time=   0.0s
# [CV 2/5] END .......alpha=0.004094915062380427;, score=-0.083 total time=   0.0s
# [CV 3/5] END .......alpha=0.004094915062380427;, score=-0.089 total time=   0.0s
# [CV 4/5] END .......alpha=0.004094915062380427;, score=-0.153 total time=   0.0s
# [CV 5/5] END .......alpha=0.004094915062380427;, score=-0.068 total time=   0.0s
# [CV 1/5] END .......alpha=0.005428675439323859;, score=-0.044 total time=   0.0s
# [CV 2/5] END .......alpha=0.005428675439323859;, score=-0.083 total time=   0.0s
# [CV 3/5] END .......alpha=0.005428675439323859;, score=-0.089 total time=   0.0s
# [CV 4/5] END .......alpha=0.005428675439323859;, score=-0.153 total time=   0.0s
# [CV 5/5] END .......alpha=0.005428675439323859;, score=-0.068 total time=   0.0s
# [CV 1/5] END ......alpha=0.0071968567300115215;, score=-0.044 total time=   0.0s
# [CV 2/5] END ......alpha=0.0071968567300115215;, score=-0.084 total time=   0.0s
# [CV 3/5] END ......alpha=0.0071968567300115215;, score=-0.089 total time=   0.0s
# [CV 4/5] END ......alpha=0.0071968567300115215;, score=-0.154 total time=   0.0s
# [CV 5/5] END ......alpha=0.0071968567300115215;, score=-0.067 total time=   0.0s
# [CV 1/5] END .......alpha=0.009540954763499945;, score=-0.044 total time=   0.0s
# [CV 2/5] END .......alpha=0.009540954763499945;, score=-0.084 total time=   0.0s
# [CV 3/5] END .......alpha=0.009540954763499945;, score=-0.089 total time=   0.0s
# [CV 4/5] END .......alpha=0.009540954763499945;, score=-0.154 total time=   0.0s
# [CV 5/5] END .......alpha=0.009540954763499945;, score=-0.066 total time=   0.0s
# [CV 1/5] END .......alpha=0.012648552168552958;, score=-0.043 total time=   0.0s
# [CV 2/5] END .......alpha=0.012648552168552958;, score=-0.084 total time=   0.0s
# [CV 3/5] END .......alpha=0.012648552168552958;, score=-0.088 total time=   0.0s
# [CV 4/5] END .......alpha=0.012648552168552958;, score=-0.155 total time=   0.0s
# [CV 5/5] END .......alpha=0.012648552168552958;, score=-0.066 total time=   0.0s
# [CV 1/5] END .......alpha=0.016768329368110083;, score=-0.043 total time=   0.0s
# [CV 2/5] END .......alpha=0.016768329368110083;, score=-0.084 total time=   0.0s
# [CV 3/5] END .......alpha=0.016768329368110083;, score=-0.088 total time=   0.0s
# [CV 4/5] END .......alpha=0.016768329368110083;, score=-0.155 total time=   0.0s
# [CV 5/5] END .......alpha=0.016768329368110083;, score=-0.065 total time=   0.0s
# [CV 1/5] END .......alpha=0.022229964825261943;, score=-0.043 total time=   0.0s
# [CV 2/5] END .......alpha=0.022229964825261943;, score=-0.085 total time=   0.0s
# [CV 3/5] END .......alpha=0.022229964825261943;, score=-0.088 total time=   0.0s
# [CV 4/5] END .......alpha=0.022229964825261943;, score=-0.156 total time=   0.0s
# [CV 5/5] END .......alpha=0.022229964825261943;, score=-0.064 total time=   0.0s
# [CV 1/5] END .......alpha=0.029470517025518096;, score=-0.043 total time=   0.0s
# [CV 2/5] END .......alpha=0.029470517025518096;, score=-0.085 total time=   0.0s
# [CV 3/5] END .......alpha=0.029470517025518096;, score=-0.087 total time=   0.0s
# [CV 4/5] END .......alpha=0.029470517025518096;, score=-0.156 total time=   0.0s
# [CV 5/5] END .......alpha=0.029470517025518096;, score=-0.063 total time=   0.0s
# [CV 1/5] END ........alpha=0.03906939937054617;, score=-0.043 total time=   0.0s
# [CV 2/5] END ........alpha=0.03906939937054617;, score=-0.085 total time=   0.0s
# [CV 3/5] END ........alpha=0.03906939937054617;, score=-0.087 total time=   0.0s
# [CV 4/5] END ........alpha=0.03906939937054617;, score=-0.157 total time=   0.0s
# [CV 5/5] END ........alpha=0.03906939937054617;, score=-0.062 total time=   0.0s
# [CV 1/5] END .........alpha=0.0517947467923121;, score=-0.043 total time=   0.0s
# [CV 2/5] END .........alpha=0.0517947467923121;, score=-0.086 total time=   0.0s
# [CV 3/5] END .........alpha=0.0517947467923121;, score=-0.086 total time=   0.0s
# [CV 4/5] END .........alpha=0.0517947467923121;, score=-0.158 total time=   0.0s
# [CV 5/5] END .........alpha=0.0517947467923121;, score=-0.061 total time=   0.0s
# [CV 1/5] END ........alpha=0.06866488450043001;, score=-0.044 total time=   0.0s
# [CV 2/5] END ........alpha=0.06866488450043001;, score=-0.086 total time=   0.0s
# [CV 3/5] END ........alpha=0.06866488450043001;, score=-0.085 total time=   0.0s
# [CV 4/5] END ........alpha=0.06866488450043001;, score=-0.158 total time=   0.0s
# [CV 5/5] END ........alpha=0.06866488450043001;, score=-0.060 total time=   0.0s
# [CV 1/5] END ........alpha=0.09102981779915217;, score=-0.044 total time=   0.0s
# [CV 2/5] END ........alpha=0.09102981779915217;, score=-0.086 total time=   0.0s
# [CV 3/5] END ........alpha=0.09102981779915217;, score=-0.085 total time=   0.0s
# [CV 4/5] END ........alpha=0.09102981779915217;, score=-0.159 total time=   0.0s
# [CV 5/5] END ........alpha=0.09102981779915217;, score=-0.059 total time=   0.0s
# [CV 1/5] END .........alpha=0.1206792640639329;, score=-0.044 total time=   0.0s
# [CV 2/5] END .........alpha=0.1206792640639329;, score=-0.087 total time=   0.0s
# [CV 3/5] END .........alpha=0.1206792640639329;, score=-0.084 total time=   0.0s
# [CV 4/5] END .........alpha=0.1206792640639329;, score=-0.160 total time=   0.0s
# [CV 5/5] END .........alpha=0.1206792640639329;, score=-0.059 total time=   0.0s
# [CV 1/5] END ........alpha=0.15998587196060574;, score=-0.044 total time=   0.0s
# [CV 2/5] END ........alpha=0.15998587196060574;, score=-0.087 total time=   0.0s
# [CV 3/5] END ........alpha=0.15998587196060574;, score=-0.084 total time=   0.0s
# [CV 4/5] END ........alpha=0.15998587196060574;, score=-0.161 total time=   0.0s
# [CV 5/5] END ........alpha=0.15998587196060574;, score=-0.058 total time=   0.0s
# [CV 1/5] END ........alpha=0.21209508879201905;, score=-0.044 total time=   0.0s
# [CV 2/5] END ........alpha=0.21209508879201905;, score=-0.087 total time=   0.0s
# [CV 3/5] END ........alpha=0.21209508879201905;, score=-0.083 total time=   0.0s
# [CV 4/5] END ........alpha=0.21209508879201905;, score=-0.162 total time=   0.0s
# [CV 5/5] END ........alpha=0.21209508879201905;, score=-0.057 total time=   0.0s
# [CV 1/5] END ........alpha=0.28117686979742307;, score=-0.044 total time=   0.0s
# [CV 2/5] END ........alpha=0.28117686979742307;, score=-0.087 total time=   0.0s
# [CV 3/5] END ........alpha=0.28117686979742307;, score=-0.082 total time=   0.0s
# [CV 4/5] END ........alpha=0.28117686979742307;, score=-0.162 total time=   0.0s
# [CV 5/5] END ........alpha=0.28117686979742307;, score=-0.057 total time=   0.0s
# [CV 1/5] END .........alpha=0.3727593720314938;, score=-0.045 total time=   0.0s
# [CV 2/5] END .........alpha=0.3727593720314938;, score=-0.088 total time=   0.0s
# [CV 3/5] END .........alpha=0.3727593720314938;, score=-0.082 total time=   0.0s
# [CV 4/5] END .........alpha=0.3727593720314938;, score=-0.163 total time=   0.0s
# [CV 5/5] END .........alpha=0.3727593720314938;, score=-0.056 total time=   0.0s
# [CV 1/5] END ........alpha=0.49417133613238334;, score=-0.045 total time=   0.0s
# [CV 2/5] END ........alpha=0.49417133613238334;, score=-0.088 total time=   0.0s
# [CV 3/5] END ........alpha=0.49417133613238334;, score=-0.081 total time=   0.0s
# [CV 4/5] END ........alpha=0.49417133613238334;, score=-0.164 total time=   0.0s
# [CV 5/5] END ........alpha=0.49417133613238334;, score=-0.055 total time=   0.0s
# [CV 1/5] END ..........alpha=0.655128556859551;, score=-0.045 total time=   0.0s
# [CV 2/5] END ..........alpha=0.655128556859551;, score=-0.088 total time=   0.0s
# [CV 3/5] END ..........alpha=0.655128556859551;, score=-0.081 total time=   0.0s
# [CV 4/5] END ..........alpha=0.655128556859551;, score=-0.166 total time=   0.0s
# [CV 5/5] END ..........alpha=0.655128556859551;, score=-0.054 total time=   0.0s
# [CV 1/5] END ..........alpha=0.868511373751352;, score=-0.045 total time=   0.0s
# [CV 2/5] END ..........alpha=0.868511373751352;, score=-0.088 total time=   0.0s
# [CV 3/5] END ..........alpha=0.868511373751352;, score=-0.080 total time=   0.0s
# [CV 4/5] END ..........alpha=0.868511373751352;, score=-0.167 total time=   0.0s
# [CV 5/5] END ..........alpha=0.868511373751352;, score=-0.053 total time=   0.0s
# [CV 1/5] END ..........alpha=1.151395399326447;, score=-0.045 total time=   0.0s
# [CV 2/5] END ..........alpha=1.151395399326447;, score=-0.089 total time=   0.0s
# [CV 3/5] END ..........alpha=1.151395399326447;, score=-0.079 total time=   0.0s
# [CV 4/5] END ..........alpha=1.151395399326447;, score=-0.169 total time=   0.0s
# [CV 5/5] END ..........alpha=1.151395399326447;, score=-0.053 total time=   0.0s
# [CV 1/5] END .........alpha=1.5264179671752334;, score=-0.045 total time=   0.0s
# [CV 2/5] END .........alpha=1.5264179671752334;, score=-0.090 total time=   0.0s
# [CV 3/5] END .........alpha=1.5264179671752334;, score=-0.079 total time=   0.0s
# [CV 4/5] END .........alpha=1.5264179671752334;, score=-0.171 total time=   0.0s
# [CV 5/5] END .........alpha=1.5264179671752334;, score=-0.052 total time=   0.0s
# [CV 1/5] END ..........alpha=2.023589647725158;, score=-0.045 total time=   0.0s
# [CV 2/5] END ..........alpha=2.023589647725158;, score=-0.090 total time=   0.0s
# [CV 3/5] END ..........alpha=2.023589647725158;, score=-0.078 total time=   0.0s
# [CV 4/5] END ..........alpha=2.023589647725158;, score=-0.173 total time=   0.0s
# [CV 5/5] END ..........alpha=2.023589647725158;, score=-0.051 total time=   0.0s
# [CV 1/5] END .........alpha=2.6826957952797246;, score=-0.045 total time=   0.0s
# [CV 2/5] END .........alpha=2.6826957952797246;, score=-0.092 total time=   0.0s
# [CV 3/5] END .........alpha=2.6826957952797246;, score=-0.077 total time=   0.0s
# [CV 4/5] END .........alpha=2.6826957952797246;, score=-0.175 total time=   0.0s
# [CV 5/5] END .........alpha=2.6826957952797246;, score=-0.051 total time=   0.0s
# [CV 1/5] END .........alpha=3.5564803062231287;, score=-0.045 total time=   0.0s
# [CV 2/5] END .........alpha=3.5564803062231287;, score=-0.094 total time=   0.0s
# [CV 3/5] END .........alpha=3.5564803062231287;, score=-0.077 total time=   0.0s
# [CV 4/5] END .........alpha=3.5564803062231287;, score=-0.178 total time=   0.0s
# [CV 5/5] END .........alpha=3.5564803062231287;, score=-0.050 total time=   0.0s
# [CV 1/5] END ..........alpha=4.714866363457395;, score=-0.045 total time=   0.0s
# [CV 2/5] END ..........alpha=4.714866363457395;, score=-0.096 total time=   0.0s
# [CV 3/5] END ..........alpha=4.714866363457395;, score=-0.076 total time=   0.0s
# [CV 4/5] END ..........alpha=4.714866363457395;, score=-0.181 total time=   0.0s
# [CV 5/5] END ..........alpha=4.714866363457395;, score=-0.051 total time=   0.0s
# [CV 1/5] END ...........alpha=6.25055192527397;, score=-0.045 total time=   0.0s
# [CV 2/5] END ...........alpha=6.25055192527397;, score=-0.099 total time=   0.0s
# [CV 3/5] END ...........alpha=6.25055192527397;, score=-0.075 total time=   0.0s
# [CV 4/5] END ...........alpha=6.25055192527397;, score=-0.184 total time=   0.0s
# [CV 5/5] END ...........alpha=6.25055192527397;, score=-0.051 total time=   0.0s
# [CV 1/5] END ..........alpha=8.286427728546842;, score=-0.045 total time=   0.0s
# [CV 2/5] END ..........alpha=8.286427728546842;, score=-0.102 total time=   0.0s
# [CV 3/5] END ..........alpha=8.286427728546842;, score=-0.075 total time=   0.0s
# [CV 4/5] END ..........alpha=8.286427728546842;, score=-0.188 total time=   0.0s
# [CV 5/5] END ..........alpha=8.286427728546842;, score=-0.053 total time=   0.0s
# [CV 1/5] END .........alpha=10.985411419875572;, score=-0.045 total time=   0.0s
# [CV 2/5] END .........alpha=10.985411419875572;, score=-0.106 total time=   0.0s
# [CV 3/5] END .........alpha=10.985411419875572;, score=-0.074 total time=   0.0s
# [CV 4/5] END .........alpha=10.985411419875572;, score=-0.193 total time=   0.0s
# [CV 5/5] END .........alpha=10.985411419875572;, score=-0.055 total time=   0.0s
# [CV 1/5] END .........alpha=14.563484775012444;, score=-0.046 total time=   0.0s
# [CV 2/5] END .........alpha=14.563484775012444;, score=-0.112 total time=   0.0s
# [CV 3/5] END .........alpha=14.563484775012444;, score=-0.074 total time=   0.0s
# [CV 4/5] END .........alpha=14.563484775012444;, score=-0.198 total time=   0.0s
# [CV 5/5] END .........alpha=14.563484775012444;, score=-0.058 total time=   0.0s
# [CV 1/5] END .........alpha=19.306977288832496;, score=-0.048 total time=   0.0s
# [CV 2/5] END .........alpha=19.306977288832496;, score=-0.118 total time=   0.0s
# [CV 3/5] END .........alpha=19.306977288832496;, score=-0.075 total time=   0.0s
# [CV 4/5] END .........alpha=19.306977288832496;, score=-0.205 total time=   0.0s
# [CV 5/5] END .........alpha=19.306977288832496;, score=-0.061 total time=   0.0s
# [CV 1/5] END .........alpha=25.595479226995334;, score=-0.050 total time=   0.0s
# [CV 2/5] END .........alpha=25.595479226995334;, score=-0.126 total time=   0.0s
# [CV 3/5] END .........alpha=25.595479226995334;, score=-0.076 total time=   0.0s
# [CV 4/5] END .........alpha=25.595479226995334;, score=-0.213 total time=   0.0s
# [CV 5/5] END .........alpha=25.595479226995334;, score=-0.065 total time=   0.0s
# [CV 1/5] END ...........alpha=33.9322177189533;, score=-0.052 total time=   0.0s
# [CV 2/5] END ...........alpha=33.9322177189533;, score=-0.135 total time=   0.0s
# [CV 3/5] END ...........alpha=33.9322177189533;, score=-0.079 total time=   0.0s
# [CV 4/5] END ...........alpha=33.9322177189533;, score=-0.223 total time=   0.0s
# [CV 5/5] END ...........alpha=33.9322177189533;, score=-0.071 total time=   0.0s
# [CV 1/5] END ..........alpha=44.98432668969444;, score=-0.056 total time=   0.0s
# [CV 2/5] END ..........alpha=44.98432668969444;, score=-0.147 total time=   0.0s
# [CV 3/5] END ..........alpha=44.98432668969444;, score=-0.083 total time=   0.0s
# [CV 4/5] END ..........alpha=44.98432668969444;, score=-0.236 total time=   0.0s
# [CV 5/5] END ..........alpha=44.98432668969444;, score=-0.077 total time=   0.0s
# [CV 1/5] END .........alpha=59.636233165946365;, score=-0.061 total time=   0.0s
# [CV 2/5] END .........alpha=59.636233165946365;, score=-0.161 total time=   0.0s
# [CV 3/5] END .........alpha=59.636233165946365;, score=-0.090 total time=   0.0s
# [CV 4/5] END .........alpha=59.636233165946365;, score=-0.253 total time=   0.0s
# [CV 5/5] END .........alpha=59.636233165946365;, score=-0.084 total time=   0.0s
# [CV 1/5] END ..........alpha=79.06043210907701;, score=-0.068 total time=   0.0s
# [CV 2/5] END ..........alpha=79.06043210907701;, score=-0.179 total time=   0.0s
# [CV 3/5] END ..........alpha=79.06043210907701;, score=-0.099 total time=   0.0s
# [CV 4/5] END ..........alpha=79.06043210907701;, score=-0.274 total time=   0.0s
# [CV 5/5] END ..........alpha=79.06043210907701;, score=-0.092 total time=   0.0s
# [CV 1/5] END .........alpha=104.81131341546852;, score=-0.077 total time=   0.0s
# [CV 2/5] END .........alpha=104.81131341546852;, score=-0.201 total time=   0.0s
# [CV 3/5] END .........alpha=104.81131341546852;, score=-0.113 total time=   0.0s
# [CV 4/5] END .........alpha=104.81131341546852;, score=-0.301 total time=   0.0s
# [CV 5/5] END .........alpha=104.81131341546852;, score=-0.101 total time=   0.0s
# [CV 1/5] END ..........alpha=138.9495494373136;, score=-0.090 total time=   0.0s
# [CV 2/5] END ..........alpha=138.9495494373136;, score=-0.230 total time=   0.0s
# [CV 3/5] END ..........alpha=138.9495494373136;, score=-0.132 total time=   0.0s
# [CV 4/5] END ..........alpha=138.9495494373136;, score=-0.337 total time=   0.0s
# [CV 5/5] END ..........alpha=138.9495494373136;, score=-0.112 total time=   0.0s
# [CV 1/5] END .........alpha=184.20699693267164;, score=-0.109 total time=   0.0s
# [CV 2/5] END .........alpha=184.20699693267164;, score=-0.266 total time=   0.0s
# [CV 3/5] END .........alpha=184.20699693267164;, score=-0.157 total time=   0.0s
# [CV 4/5] END .........alpha=184.20699693267164;, score=-0.383 total time=   0.0s
# [CV 5/5] END .........alpha=184.20699693267164;, score=-0.126 total time=   0.0s
# [CV 1/5] END ...........alpha=244.205309454865;, score=-0.134 total time=   0.0s
# [CV 2/5] END ...........alpha=244.205309454865;, score=-0.311 total time=   0.0s
# [CV 3/5] END ...........alpha=244.205309454865;, score=-0.191 total time=   0.0s
# [CV 4/5] END ...........alpha=244.205309454865;, score=-0.440 total time=   0.0s
# [CV 5/5] END ...........alpha=244.205309454865;, score=-0.144 total time=   0.0s
# [CV 1/5] END ...........alpha=323.745754281764;, score=-0.166 total time=   0.0s
# [CV 2/5] END ...........alpha=323.745754281764;, score=-0.366 total time=   0.0s
# [CV 3/5] END ...........alpha=323.745754281764;, score=-0.234 total time=   0.0s
# [CV 4/5] END ...........alpha=323.745754281764;, score=-0.510 total time=   0.0s
# [CV 5/5] END ...........alpha=323.745754281764;, score=-0.167 total time=   0.0s
# [CV 1/5] END ..........alpha=429.1934260128778;, score=-0.208 total time=   0.0s
# [CV 2/5] END ..........alpha=429.1934260128778;, score=-0.431 total time=   0.0s
# [CV 3/5] END ..........alpha=429.1934260128778;, score=-0.286 total time=   0.0s
# [CV 4/5] END ..........alpha=429.1934260128778;, score=-0.591 total time=   0.0s
# [CV 5/5] END ..........alpha=429.1934260128778;, score=-0.196 total time=   0.0s
# [CV 1/5] END ..........alpha=568.9866029018293;, score=-0.258 total time=   0.0s
# [CV 2/5] END ..........alpha=568.9866029018293;, score=-0.504 total time=   0.0s
# [CV 3/5] END ..........alpha=568.9866029018293;, score=-0.347 total time=   0.0s
# [CV 4/5] END ..........alpha=568.9866029018293;, score=-0.682 total time=   0.0s
# [CV 5/5] END ..........alpha=568.9866029018293;, score=-0.231 total time=   0.0s
# [CV 1/5] END ..........alpha=754.3120063354608;, score=-0.314 total time=   0.0s
# [CV 2/5] END ..........alpha=754.3120063354608;, score=-0.581 total time=   0.0s
# [CV 3/5] END ..........alpha=754.3120063354608;, score=-0.413 total time=   0.0s
# [CV 4/5] END ..........alpha=754.3120063354608;, score=-0.779 total time=   0.0s
# [CV 5/5] END ..........alpha=754.3120063354608;, score=-0.271 total time=   0.0s
# [CV 1/5] END .....................alpha=1000.0;, score=-0.373 total time=   0.0s
# [CV 2/5] END .....................alpha=1000.0;, score=-0.661 total time=   0.0s
# [CV 3/5] END .....................alpha=1000.0;, score=-0.482 total time=   0.0s
# [CV 4/5] END .....................alpha=1000.0;, score=-0.876 total time=   0.0s
# [CV 5/5] END .....................alpha=1000.0;, score=-0.313 total time=   0.0s
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([1.00000000e-03, 1.32571137e-03, 1.75751062e-03, 2.32995181e-03,
#        3.08884360e-03, 4.09491506e-03, 5.42867544e-03, 7.19685673e-03,
#        9.54095476e-03, 1.26485522e-02, 1.67683294e-02, 2.22299648e-02,
#        2.94705170e-02, 3.90693994e-02, 5.17947468e-02, 6.86648845e-02,
#        9.10298178e-02, 1.20679264e-01, 1.59985872e-01, 2....
#        2.68269580e+00, 3.55648031e+00, 4.71486636e+00, 6.25055193e+00,
#        8.28642773e+00, 1.09854114e+01, 1.45634848e+01, 1.93069773e+01,
#        2.55954792e+01, 3.39322177e+01, 4.49843267e+01, 5.96362332e+01,
#        7.90604321e+01, 1.04811313e+02, 1.38949549e+02, 1.84206997e+02,
#        2.44205309e+02, 3.23745754e+02, 4.29193426e+02, 5.68986603e+02,
#        7.54312006e+02, 1.00000000e+03])},
#              scoring='neg_mean_squared_error', verbose=3)

# %% [markdown]
# Внутри модели все значения score отсортировываются, поэтому мы сразу можем вывести наилучшее значение для регуляризационного параметра (то есть при котором минимальное значение минимизируемой метрики)

# %%
print("Лучшее значение alpha для Ridge:", ridge_cv.best_params_)
# Out:
# Лучшее значение alpha для Ridge: {'alpha': 0.28117686979742307}

# %% [markdown]
# Также мы можем сразу получить модель, с подставленным наилучшим значением `alpha`:

# %%
best_ridge = ridge_cv.best_estimator_
best_ridge
# Out:
# Ridge(alpha=0.28117686979742307)

# %% [markdown]
# То есть в `best_ridge` записана наилучшая Ridge регрессия в смысле регуляризационного коэффициента `alpha`. Расчитаем все метрики для этой модели

# %%
y_hat = best_ridge.predict(X_train)
y_pred = best_ridge.predict(X_test)

# %%
metrics(y_train, y_hat, y_test, y_pred)

# %% [markdown]
# > Сравните получившиеся значения метрик. В каком случае метрики лучше: в классической LinearRegression или в Ridge?
#
# > Попробуйте поменять метрику кросс-валидации (то есть с MSE на R^2) и сравнить результаты; попробуйте поменять количество разбиений

# %% [markdown]
# ### LASSO

# %% [markdown]
# Проделаем все аналогичные действия теперь для LASSO

# %%
lasso = Lasso(max_iter=10000)  # Увеличиваем max_iter, чтобы избежать проблем с сходимостью

# YOUR CODE
# Hint: по сути требуется повторить те же действия, которые были проделаны для Ridge модели

# %% [markdown]
# > Сравните получившиеся значения метрик. В каком случае метрики лучше: в классической LinearRegression, Ridge или LASSO?
#
# > Попробуйте поменять метрику кросс-валидации (то есть с MSE на R^2) и сравнить результаты; попробуйте поменять количество разбиений

# %% [markdown]
# ## Полиномиальные регрессии

# %% [markdown]
# Вернемся к диаграммам рассеяния по видам и можем увидеть, что, например, для рыб вида `Pike`, взаимосвязь между `Weight` и фичами не совсем линейная, а немного кривая. Поэтому мы можем попробовать аппроксимировать взаимосвязь не линейной функцией
# $$
# f(x,w) = (x,w),
# $$
# а квадратичной
# $$
# f(x,w, w) = (x,w) + (x^2, w')
# $$
# или кубической. Тогда появляется один дополнительный вектор параметров $w' \in \mathbb R^m$. То есть параметров для оценки становится больше, модель становится сложнее, но результаты могут оказаться лучше.
#
# Попробуем добавить признаки 2-ой, 3-ей и 4-ой степеней в модель

# %%
degrees = [2, 3, 4]

for degree in degrees:
    # Создаём пайплайн: сначала преобразуем полиномиальные признаки, затем применяем линейную регрессию
    model = Pipeline([
        ('poly_features', PolynomialFeatures(degree=degree)),
        ('linear_regression', LinearRegression())
    ])

    # Обучение модели
    model.fit(X_train, y_train)

    # Значения метрик
    print(f'Метрики в случае полиномиальных признаков {degree} порядка')

    # YOUR CODE

    print('_______________________________________________')
# Out:
# Метрики в случае полиномиальных признаков 2 порядка
# _______________________________________________
# Метрики в случае полиномиальных признаков 3 порядка
# _______________________________________________
# Метрики в случае полиномиальных признаков 4 порядка
# _______________________________________________

# %% [markdown]
# > Сравните получившиеся значения метрик. В каком случае метрики лучше ?
#
# > Происходит ли переобучение? Если да, то с какой степени полиномов модель будет переобучаться? Если нет, то попробуйте добавить степени полиномов и посмотреть, что получится

# %% [markdown]
# ## Выводы

# %% [markdown]
# Таким образом, лучшей моделью для решения задачи прогнозирования веса рыбы является модель -- ___________.
#
# Она имеет следующие метрики:
# - На Обучающем наборе
# - - $MSE$ : ___________
#   - $R^2$ : ___________
# - На Тестовом наборе
# - - $MSE$ : ___________
#   - $R^2$ : ___________

# %% [markdown]
# > В качестве доп. задания рекомендуется также исследовать значимость коэффициентов моделей и поведение остатков моделей. Сделайте соответствующие выводы
